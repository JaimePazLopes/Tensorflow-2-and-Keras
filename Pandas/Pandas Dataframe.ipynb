# %%
import numpy as np
import pandas as pd

# %%
columns = ["W", "X", "Y", "Z"]

# %%
index = ["A", "B", "C", "D", "E"]

# %%
from numpy.random import randint

# %%
np.random.seed(42)
data = randint(-100, 100, (5,4))

# %%
data
# Out:
# array([[  2,  79,  -8, -86],
#        [  6, -29,  88, -80],
#        [  2,  21, -26, -13],
#        [ 16,  -1,   3,  51],
#        [ 30,  49, -48, -99]])

# %%
df = pd.DataFrame(data, index, columns)

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df["W"]
# Out:
# A     2
# B     6
# C     2
# D    16
# E    30
# Name: W, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["W"])
# Out:
# pandas.core.series.Series

# %%
df["W"]["A"]
# Out:
# 2

# %%
df[["W", "Z"]]
# Out:
#     W   Z
# A   2 -86
# B   6 -80
# C   2 -13
# D  16  51
# E  30 -99

# %%
df["new"] = df["W"] + df["Y"]

# %%
df
# Out:
#     W   X   Y   Z  new
# A   2  79  -8 -86   -6
# B   6 -29  88 -80   94
# C   2  21 -26 -13  -24
# D  16  -1   3  51   19
# E  30  49 -48 -99  -18

# %%
df = df.drop("new", axis=1)

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df.loc["A"]
# Out:
# W     2
# X    79
# Y    -8
# Z   -86
# Name: A, dtype: int64

# %%
df.loc[["A", "E"]]
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# E  30  49 -48 -99

# %%
df.iloc[0]
# Out:
# W     2
# X    79
# Y    -8
# Z   -86
# Name: A, dtype: int64

# %%
df.iloc[-1]
# Out:
# W    30
# X    49
# Y   -48
# Z   -99
# Name: E, dtype: int64

# %%
df.iloc[1:3]
# Out:
#    W   X   Y   Z
# B  6 -29  88 -80
# C  2  21 -26 -13

# %%
df.drop("C")
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df = df.drop("C")

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df.loc["A", "W"]
# Out:
# 2

# %%
df.loc[["A", "B"], "W"]
# Out:
# A    2
# B    6
# Name: W, dtype: int64

# %%
df > 0
# Out:
#       W      X      Y      Z
# A  True   True  False  False
# B  True  False   True  False
# D  True  False   True   True
# E  True   True  False  False

# %%
df[df>0]
# Out:
#     W     X     Y     Z
# A   2  79.0   NaN   NaN
# B   6   NaN  88.0   NaN
# D  16   NaN   3.0  51.0
# E  30  49.0   NaN   NaN

# %%
df["X"] > 0
# Out:
# A     True
# B    False
# D    False
# E     True
# Name: X, dtype: bool

# %%
df[df["X"] > 0]
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# E  30  49 -48 -99

# %%
df[df["X"] > 0]["W"]
# Out:
# A     2
# E    30
# Name: W, dtype: int64

# %%
df[df["X"] > 0].iloc[0]
# Out:
# W     2
# X    79
# Y    -8
# Z   -86
# Name: A, dtype: int64

# %%
df[(df["W"] > 0) & (df["Y"] > 1)]
# Out:
#     W   X   Y   Z
# B   6 -29  88 -80
# D  16  -1   3  51

# %%
df[(df["W"] > 0) | (df["Y"] > 1)]
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df.reset_index()
# Out:
#   index   W   X   Y   Z
# 0     A   2  79  -8 -86
# 1     B   6 -29  88 -80
# 2     D  16  -1   3  51
# 3     E  30  49 -48 -99

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
new_ind = ["CA", "NY", "WY", "OR"]

# %%
df["States"] = new_ind

# %%
df
# Out:
#     W   X   Y   Z States
# A   2  79  -8 -86     CA
# B   6 -29  88 -80     NY
# D  16  -1   3  51     WY
# E  30  49 -48 -99     OR

# %%
df.set_index("States")
# Out:
#          W   X   Y   Z
# States
# CA       2  79  -8 -86
# NY       6 -29  88 -80
# WY      16  -1   3  51
# OR      30  49 -48 -99

# %%
df
# Out:
#     W   X   Y   Z States
# A   2  79  -8 -86     CA
# B   6 -29  88 -80     NY
# D  16  -1   3  51     WY
# E  30  49 -48 -99     OR

# %%
df = df.set_index("States")

# %%
df
# Out:
#          W   X   Y   Z
# States
# CA       2  79  -8 -86
# NY       6 -29  88 -80
# WY      16  -1   3  51
# OR      30  49 -48 -99

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.describe()
# Out:
#                W          X          Y         Z
# count   4.000000   4.000000   4.000000   4.00000
# mean   13.500000  24.500000   8.750000 -53.50000
# std    12.476645  48.590122  57.197756  70.11657
# min     2.000000 -29.000000 -48.000000 -99.00000
# 25%     5.000000  -8.000000 -18.000000 -89.25000
# 50%    11.000000  24.000000  -2.500000 -83.00000
# 75%    19.500000  56.500000  24.250000 -47.25000
# max    30.000000  79.000000  88.000000  51.00000

# %%
df.head()
# Out:
#          W   X   Y   Z
# States
# CA       2  79  -8 -86
# NY       6 -29  88 -80
# WY      16  -1   3  51
# OR      30  49 -48 -99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to OR
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       4 non-null      int64
#  1   X       4 non-null      int64
#  2   Y       4 non-null      int64
#  3   Z       4 non-null      int64
# dtypes: int64(4)
# memory usage: 160.0+ bytes

# %%
df.dtypes
# Out:
# W    int64
# X    int64
# Y    int64
# Z    int64
# dtype: object
